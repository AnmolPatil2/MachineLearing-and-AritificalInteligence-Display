# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
data = pd.read_csv("mobiledata.csv",encoding='unicode_escape')
data.rename(columns={' PRICE ':'PRICE'},inplace=True)
data
# Out:
#        BRAND       OS VERSION  RAM MEMORY   DISPLAY          MODEL NO  \
# 0       OPPO  ANDROID     7.1  3GB   16GB  5.2 inch               A71
# 1       OPPO  ANDROID     5.1  2GB   16GB    5 inch               A37
# 2       OPPO  ANDROID       6  4GB   64GB  5.5 inch                F3
# 3       OPPO  ANDROID     7.1  6GB   64GB    6 inch                F5
# 4       OPPO  ANDROID   7.1.1  3GB   32GB    6 inch                F5
# 5       OPPO  ANDROID     7.1  3GB   32GB  5.7 inch               A83
# 6       OPPO  ANDROID     5.1  3GB   32GB  5.5 inch               F1S
# 7       OPPO  ANDROID     5.1  3GB   16GB    5 inch                F1
# 8       OPPO  ANDROID     4.2  2GB   16GB  5.9 inch                N1
# 9       OPPO  ANDROID     4.3  1GB    4GB  4.5 inch             Neo 5
# 10      OPPO  ANDROID     5.1  1GB   16GB    5 inch             Neo 7
# 11      OPPO  ANDROID     7.1  4GB   32GB    6 inch                F5
# 12      OPPO  ANDROID       6  4GB   64GB    6 inch           F3 Plus
# 13      OPPO  ANDROID     5.1  2GB   16GB    5 inch              A51w
# 14      OPPO  ANDROID     5.1  2GB   16GB    5 inch           R7 Lite
# 15     REDMI  ANDROID   6.0.1  2GB   16GB     5inch           Redmi 4
# 16     REDMI  ANDROID   6.0.1  3GB   32GB     5inch          Redmi 4A
# 17     REDMI  ANDROID   6.0.1  2GB   16GB    5 inch                 4
# 18     REDMI  ANDROID   7.1.2  3GB   32GB  5.5 inch                Y1
# 19     REDMI  ANDROID   7.1.2  2GB   16GB  5.5 inch           Y1 Lite
# 20     REDMI  ANDROID   6.0.1  4GB   64GB  5.5 inch            Note 4
# 21     REDMI  ANDROID   6.0.1  3GB   32GB    5 inch                 4
# 22     REDMI  ANDROID     7.1  2GB   16GB    5 inch                5A
# 23       HTC  ANDROID       8  6GB  128GB     6inch              U11+
# 24       HTC  ANDROID       6  4GB   64GB  5.5 inch            10 Pro
# 25       HTC  ANDROID     5.1  3GB   32GB  5.0 inch               628
# 26       HTC  ANDROID       6  4GB   64GB  5.2 inch            U Play
# 27       HTC  ANDROID   7.1.1  4GB   64GB  5.7 inch           U Ultra
# 28       HTC  ANDROID     5.1  3GB   32GB  5.5 inch               828
# 29       HTC  ANDROID   4.4.4  1GB    8GB    5 inch              620G
# ..       ...      ...     ...  ...    ...       ...               ...
# 233     LAVA  ANDROID       7  3GB   32GB  5.2 inch               Z90
# 234     LAVA  ANDROID       7  1GB    8GB    4 inch               A44
# 235     LAVA  ANDROID       7  3GB   16GB    5 inch               Z80
# 236     LAVA  ANDROID     4.4  2GB   16GB    5 inch           Iris X8
# 237    INTEX  ANDROID       6  1GB    8GB  5.5 inch         Cloud Q11
# 238    INTEX  ANDROID       7  2GB   16GB    5 inch     Aqua ElytDual
# 239    INTEX  ANDROID       6  1GB    8GB    5 inch  Aqua Strong 5.1+
# 240    INTEX  ANDROID       7  1GB    8GB    4 inch          Cloud C1
# 241    INTEX  ANDROID       6  2GB   16GB    5 inch     Aqua Supreme+
# 242    INTEX  ANDROID       7  3GB   32GB  5.2 inch   Aqua Lions- X1+
# 243    INTEX  ANDROID       7  2GB   16GB  5.5 inch          Note 5.5
# 244    INTEX  ANDROID       7  2GB   16GB  5.5 inch       Aqua Selfie
# 245    INTEX  ANDROID       7  1GB   16GB    5 inch      Aqua Style 3
# 246    INTEX  ANDROID       7  1GB    8GB    5 inch           Aqua S1
# 247    INTEX  ANDROID       7  1GB    8GB    4 inch           Aqua A4
# 248  KARBONN  ANDROID       6  2GB   16GB  5.5 inch      Aura Note 4G
# 249  KARBONN  ANDROID       7  2GB   16GB    5 inch    Titanium Jumbo
# 250  KARBONN  ANDROID       6  1GB    8GB    5 inch       K9 Smart 4G
# 251  KARBONN  ANDROID     7.1  1GB    8GB    4 inch      A1 Indian 4G
# 252  KARBONN  ANDROID       7  2GB   16GB  5.5 inch  Titanium Jumbo 2
# 253  KARBONN  ANDROID       7  1GB    8GB    5 inch      K9 Smart Eco
# 254  COOLPAD  ANDROID       6  4GB   32GB  5.5 inch            Cool 1
# 255  COOLPAD  ANDROID     7.1  6GB   64GB  5.5 inch       Cool Play 6
# 256  COOLPAD  ANDROID       6  3GB   16GB    5 inch       Note 5 Lite
# 257  COOLPAD  ANDROID       6  4GB   32GB  5.5 inch            Note 5
# 258  COOLPAD  ANDROID       6  3GB   32GB    5 inch       Note 5 Lite
# 259  COOLPAD  ANDROID     NaN  3GB   32GB  5.5 inch            Cool 1
# 260  COOLPAD  ANDROID       6  3GB   32GB  5.5 inch           Note 3S
# 261  COOLPAD  ANDROID     5.1  4GB   64GB  5.5 inch           Max A-8
# 262  COOLPAD  ANDROID       6  2GB   16GB    5 inch     Note 5 Lite C
#
#     PRIMARYCAMERA SECONDARYCAMERA  BATTERY      COLOR PROCESSOR   DIMENSION  \
# 0            13MP             5MP  3000mAh       Gold     Octa     87.61600
# 1             8MP             5MP  2630mAh       Gold      Quad    81.22400
# 2            13MP            16MP  3200mAh       Gold     Octa     80.32500
# 3            16MP            20MP  3200mAh      Black     Octa     95.45600
# 4            13MP            16MP  3200mAh      Black     Octa     95.45600
# 5            13MP             8MP  3180mAh  Champagne     Octa     88.18400
# 6            13MP            16MP  3075mAh       Gold     Octa     82.46000
# 7            13MP             8MP  2500mAh       Gold     Octa     71.56800
# 8            13MP             NaN  3610mAh      White     Quad    127.73700
# 9             5MP             2MP  1900mAh      Black      Quad    78.40800
# 10            8MP             5MP  2420mAh      Black     Quad     82.36800
# 11           16MP            20MP  3200mAh       Blue      Octa    95.45600
# 12           16MP            16MP  4000mAh       Gold     Octa     92.98800
# 13            8MP             5MP  2420mAh       Blue     Quad     81.22400
# 14           13MP             8MP  2320mAh       Gold     Octa     60.91800
# 15           13MP             5MP  4100mAh      BLACK     Octa    182.52000
# 16           13MP             5MP  3120mAH       GOLD      Quad    99.90000
# 17           13MP             5MP  4100mAh      Black      octa    87.57000
# 18           13MP            16MP  3080mAh       Gold      Octa    93.02400
# 19           13MP             5MP  3080mAh       Gold      Quad    93.02400
# 20           13MP             5MP  4100mAh       Grey     Octa     91.80800
# 21           13MP             5MP  4100mAh       Gold     Octa     87.57000
# 22           13MP             5MP  3000mAh      Black      Quad    78.73632
# 23           12MP             8MP  3930mAh     Silver     Octa     93.63200
# 24           20MP            13MP  3000mAh      White      Octa    95.45600
# 25           13MP             5MP  2200mAh      White     Octa     83.49600
# 26           16MP            16MP  2435mAh      Black     Octa     85.26400
# 27           12MP            16MP  3000mAh      Black      Quad   964.81000
# 28           13MP             4MP  2800mAh       Grey     Octa     99.85600
# 29            8MP             5MP  2100mAh      White     Octa    109.50000
# ..            ...             ...      ...        ...       ...         ...
# 233           8MP             5MP  2750mAh       Blue      Quad    87.01600
# 234           5MP             2MP  1500mAh      Black      Quad    78.72000
# 235           8MP             5MP  2500mAh      Black      Quad    81.79200
# 236           8MP             3MP  2500mAh      White      Octa    91.37700
# 237           8MP             5MP  2800mAh      White      Quad    18.72000
# 238           8MP             2MP  2400mAh  Champagne      Quad    93.96000
# 239           5MP             2MP  2000mAh       Gold      Quad   102.96000
# 240           5MP             2MP  1750mAh      Black      Quad    88.00000
# 241          13MP             5MP  3000mAh  Champagne      Quad    82.36800
# 242          13MP             5MP      NaN  Champagne      Quad   998.99700
# 243           8MP             5MP  2800mAh  Champagne      Quad   119.34000
# 244           8MP             5MP  3000mAh      Black      Quad   965.32800
# 245           5MP             5MP  2500mAh  Champagne      Quad   106.58000
# 246           5MP             5MP  2300mAh  Champagne      Quad   106.58000
# 247           5MP             2MP  1750mAh      Black      Quad  1424.30400
# 248           5MP             5MP  2800mAh  Champagne      Quad   123.20000
# 249          13MP             8MP  4000mAh      Black      Quad  6424.70400
# 250         3.2MP           1.3MP  2300mAh      Black     Dual    808.70400
# 251         3.2MP             2MP  1500mAh       Blue      Quad    76.88000
# 252          13MP             8MP  4000mAh      Black      Quad     7.54000
# 253           2MP             2MP  2300mAh      Black      Quad   114.84000
# 254          13MP             8MP  4000mAh       Gold      Octa    91.20000
# 255          13MP             8MP  4000mAh      Black      Octa   103.27500
# 256          13MP             8MP  2500mAh       Grey      Quad    93.96000
# 257          13MP             8MP  4010mAh       Grey      Octa   103.96800
# 258          13MP             8MP  2500mAh       Gold      Quad    93.96000
# 259          13MP             8MP  4000mAh       Gold      Octa    91.20000
# 260          13MP             5MP  2500mAh      White      Octa    95.48000
# 261          13MP             5MP  2800mAh       Gold      Octa  1177.08800
# 262           8MP             5MP  2500mAh  Champagne      Quad    93.96000
#
#      WEIGHT TECHNOLOGY  PRICE
# 0      136g         4G  10990
# 1      136g         4G  10990
# 2      154g         4G  20990
# 3      154g         4G  25990
# 4      154g         4G  17999
# 5      145g         4G  14990
# 6      159g         4G  17850
# 7      136g         3G  11961
# 8      213g         3G  29990
# 9      132g         4G   8999
# 10     141g         3G   8999
# 11     154g         4G  20990
# 12     186g         4G  30990
# 13     159g         4G  20000
# 14     145g         4G  13999
# 15     150g         4G   7999
# 16   131.5g         4G   6999
# 17     150g         4G   6999
# 18     154g         4G   9999
# 19     154g         4G   7999
# 20     163g         4G  12999
# 21     150g         4G   8999
# 22     137g         4G   4999
# 23     190g         4G  56990
# 24     163g         4G  27990
# 25     141g         4G   9999
# 26     145g         4G  41990
# 27     440g         4G  27990
# 28     150g         3G   9000
# 29     159g         3G   9999
# ..      ...        ...    ...
# 233    159g         4G  12499
# 234    141g         4G   5399
# 235    136g         4G   9999
# 236    159g         3G   6850
# 237    154g         3G   5061
# 238    150g         4G   8499
# 239    150g         4G   5899
# 240    118g         4G   4499
# 241    132g         4G   8999
# 242    408g         4G  10520
# 243    177g         4G   6199
# 244    177g         4G   7499
# 245    163g         4G   5899
# 246    159g         4G   4549
# 247    118g         4G   4999
# 248    136g         4G   7490
# 249    172g         4G   7499
# 250    340g         4G   5490
# 251    118g         4G   4390
# 252    168g         4G   8490
# 253    154g         3G   3990
# 254    172g         4G  14999
# 255    177g         4G  17999
# 256    150g         4G   8999
# 257    172g         4G  11999
# 258    150g         4G   9999
# 259    172g         4G  11999
# 260    445g         4G  10999
# 261    599g         4G  13999
# 262    150g         4G   8999
#
# [263 rows x 16 columns]

# %% [markdown]
# # BRAND

# %%
data['BRAND']=data.BRAND.map({'APPLE':57000,'ASUS':20000,'COOLPAD':12000,'HONOR':17000,'HTC':19500,'INTEX':6500,'KARBONN':6200,'LAVA':7000,'LENOVO':13000,'LG':22500,'MICROSOFT':12000,'MOTO':17500,'NOKIA':11200,'ONEPLUS':32000,'OPPO':17000,'PANASONIC':9500,'REDMI':8300,'SAMSUNG':26000,'SONY':26500,'VIVO':17000,'MICROMAX':13500})

# %%
V=data[['BRAND','PRICE','OS','COLOR']]
V2=V.groupby(['BRAND'], as_index=False).mean()
V2.sort_values('PRICE',inplace=True)
V2.set_index('BRAND',inplace=True)
V2
# Out:
#               PRICE
# BRAND
# 6200    6224.833333
# 6500    6602.000000
# 7000    7184.857143
# 8300    8374.000000
# 9500    9670.941176
# 11200  11210.200000
# 12000  12065.722222
# 13000  13224.625000
# 13500  13410.571429
# 17000  17194.930233
# 17500  17507.733333
# 19500  19634.764706
# 20000  19783.117647
# 22500  23595.666667
# 26000  26396.333333
# 26500  26734.545455
# 32000  32999.000000
# 57000  57590.727273

# %%
'''''V2.plot(kind='bar', figsize=(10, 6), rot=90) # rotate the bars by 90 degrees

plt.xlabel('brands')
plt.ylabel('price')
plt.title('Average Price')

plt.show()'''''
# Out:
# "''V2.plot(kind='bar', figsize=(10, 6), rot=90) # rotate the bars by 90 degrees\n\nplt.xlabel('brands')\nplt.ylabel('price')\nplt.title('Average Price')\n\nplt.show()"

# %% [markdown]
# # OS

# %%
data['OS']=data.OS.map({'ANDROID':16903,'iOS':57590,'WINDOWS':10707})

# %%
V=data[['PRICE','OS']]
V3=V.groupby(['OS'], as_index=False).mean()
V3.sort_values('PRICE',inplace=True)
V3.set_index('OS',inplace=True)
V3
# Out:
#               PRICE
# OS
# 10707  10707.071429
# 16903  16903.432773
# 57590  57590.727273

# %%
colors_list = ['gold', 'yellowgreen', 'lightcoral']
explode_list = [0.1, 0, 0.1] # ratio for each continent with which to offset each wedge.

V3.plot(kind='pie',
                            figsize=(15, 6),
                            autopct='%1.1f%%', 
                            startangle=90,    
                            shadow=True,       
                            labels=None,
                            subplots=True,
                            pctdistance=1.12,    # the ratio between the center of each pie slice and the start of the text generated by autopct 
                            colors=colors_list,  # add custom colors
                            explode=explode_list # 'explode' lowest 3 continents
                            )

# scale the title up by 12% to match pctdistance
plt.title('OS') 

plt.axis('equal') 

# add legend
plt.legend(labels=V3.index, loc='upper left') 

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # VERSION

# %%
version = data["VERSION"].apply(lambda x : str(x).strip(" "))
version = version.replace(['','nan'],[7,7])
v = version.replace(['7.1.1','6.0.1','7.1.2','4.4.4','5.1.1','4.4.2','4.2.1','4.2.2','5.0.2','11.1.1','10.0.1'],
                             [7,6,7,4,5,4,4,4,5,11,10])
v = v.replace(['7.1','5.1','4.2','4.3','4.4','8.1','6.01'],
             [7,5,4,4,4,8,6])
v = pd.to_numeric(v)
data["VERSION"] = v

# %%
data["VERSION"].value_counts()
# Out:
# 7     101
# 6      70
# 5      38
# 4      23
# 8      15
# 10     11
# 11      5
# Name: VERSION, dtype: int64

# %%
V=data[['PRICE','VERSION']]
V3=V.groupby(['VERSION'], as_index=False).mean()
V3.sort_values('PRICE',inplace=True)
V3.set_index('VERSION',inplace=True)
V3
# Out:
#                 PRICE
# VERSION
# 5        13585.789474
# 8        13712.666667
# 4        14885.521739
# 6        16621.457143
# 7        18670.603960
# 10       27351.272727
# 11       78400.000000

# %%
colors_list = ['gold', 'yellowgreen', 'lightcoral','red','pink','green','blue']
explode_list = [0, 0, 0,0
                ,0,0.1,0.1] # ratio for each continent with which to offset each wedge.

V3.plot(kind='pie',
                            figsize=(15, 6),
                            autopct='%1.1f%%', 
                            startangle=90,    
                            shadow=True,       
                            labels=None,
                            subplots=True,
                            pctdistance=1.12,    # the ratio between the center of each pie slice and the start of the text generated by autopct 
                            colors=colors_list,  # add custom colors
                             # 'explode' lowest 3 continents
                            )

# scale the title up by 12% to match pctdistance
plt.title('OS') 

plt.axis('equal') 

# add legend
plt.legend(labels=V3.index, loc='upper left') 

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # RAM

# %%
data["RAM"] = data["RAM"].replace(['512MB'],'0.5GB')
data["RAM"] = data["RAM"].apply(lambda x : str(x).strip(" "))
R = []

for r in data["RAM"]:
    R.append(str(r)[:-2])
    
data["RAM"]=R

# %% [markdown]
# # MEMORY

# %%
data["MEMORY"] = data["MEMORY"].apply(lambda x : str(x).strip(" "))
M= []

for m in data["MEMORY"]:
    M.append(str(m)[:-2])
    
data["MEMORY"] = M

# %%
V=data[['PRICE',"MEMORY"]]
V3=V.groupby(["MEMORY"], as_index=False).count()

V3.set_index("MEMORY",inplace=True)
V3
# Out:
#         PRICE
# MEMORY
# 128         8
# 16         86
# 256         2
# 32         73
# 4           6
# 64         50
# 8          38

# %% [markdown]
# # DISPLAY

# %%
data["DISPLAY"] = data["DISPLAY"].apply(lambda x : str(x).strip(" "))
D = []

for d in data["DISPLAY"]:
    D.append(str(d)[:-4])
    
D = pd.Series(D).apply(lambda x : str(x).strip(" "))
D = D.replace([''],['5.5'])
D= pd.to_numeric(D)
data["DISPLAY"] = D

# %%
import seaborn as sns
sns.regplot(x='DISPLAY', y='PRICE', data=data)

# %% [markdown]
# # PRIMARY CAMERA

# %%
data["PRIMARYCAMERA"] = data["PRIMARYCAMERA"].apply(lambda x : str(x).strip(" "))

P = []

for p in data["PRIMARYCAMERA"]:
     P.append(str(p)[:-2])
        
P = pd.Series(P).replace(['v','n'],['0.3','13'])
     
data["PRIMARYCAMERA"] = P

# %% [markdown]
# # Secondary camera

# %%
data["SECONDARYCAMERA"] = data["SECONDARYCAMERA"].apply(lambda x : str(x).strip(" "))

S = []

for s in data["SECONDARYCAMERA"]:
     S.append(str(s)[:-2])

S = pd.Series(S).replace(['n'],['5'])

data["SECONDARYCAMERA"] = S

# %% [markdown]
# # BATTERY

# %%
B = data["BATTERY"].apply(lambda x : str(x).strip("  "))


b = []
for a in B:
    z = a[0:4]
    b.append(z)
    
    
battery = pd.Series(b)

battery.replace(to_replace = ['nan','300m'],value = [0,'3000'],inplace=True)

Battery = []
for r in battery:
    if (int(r) <= 1500):
        r = 1500
        Battery.append(r)
    elif(int(r)>1500 and int(r)<=2000):
        r = 2000
        Battery.append(r)
    elif(int(r)>2000 and int(r)<=2500):
        r = 2500
        Battery.append(r)
    elif(int(r)>2500 and int(r)<=3000):
        r = 3000
        Battery.append(r)
    elif(int(r)>3000 and int(r)<=3500):
        r = 3500
        Battery.append(r)
    elif(int(r)>3500 and int(r)<=4000):
        r = 4000
        Battery.append(r)
    elif(int(r)>4000 and int(r)<=4500):
        r = 4500
        Battery.append(r)
    elif(int(r)>4500 and int(r)<=5000):
        r = 5000
        Battery.append(r)

data["BATTERY"] = Battery

# %% [markdown]
# # COLOR

# %%
data["COLOR"]  = data["COLOR"].apply(lambda x : str(x).strip(" "))
data["COLOR"]  = data["COLOR"].apply(lambda x : x.lower())

# %% [markdown]
# # PROCESSOR

# %%
Processor = []
for a in data["PROCESSOR"]:
    b = str(a).lower()
    Processor.append(b)
    
P = pd.Series(Processor).apply(lambda x: str(x).strip(" "))

p = []
for a in P:
    if(a == "dual"):
        a = 2
        p.append(a)
    elif(a == "quad"):
        a = 4
        p.append(a)
    elif(a == "hexa"):
        a = 6
        p.append(a)
    elif(a == "octa"):
        a = 8
        p.append(a)
    elif(a == "deca"):
        a = 10
        p.append(a)
    else:
        a = 0
        p.append(a)
        
data["PROCESSOR"] = p

# %% [markdown]
# # DIMENSION

# %%
Display = data['DIMENSION'].apply(lambda x : str(x).split(".")[0])
Display = Display.replace(['101970','nan'],['1019','0'])
data["DIMENSION"] = Display

# %% [markdown]
# # WEIGHT

# %%
W = data["WEIGHT"].apply(lambda x : str(x).strip(" "))

# %%
weight = []
for c in W:
    if( c == 'nan'):
        b = 0
        weight.append(b)
    elif(c == '2.43Kg'):
        b = '243'
        weight.append(b)
    else:
        b = c[:3]
        weight.append(b)

    
data["WEIGHT"] = weight

# %% [markdown]
# # TECHNOLOGY

# %%
technology = data["TECHNOLOGY"].apply(lambda x : str(x).strip(" "))
t = technology.replace(['4G','3G','2G','nan'],[4,3,2,4])
data["TECHNOLOGY"] = t

# %%
data[['RAM','PRIMARYCAMERA','SECONDARYCAMERA','DIMENSION','WEIGHT','MEMORY']]=data[['RAM','PRIMARYCAMERA','SECONDARYCAMERA','DIMENSION','WEIGHT','MEMORY']].applymap(float)

# %%
data.corr()["PRICE"]
# Out:
# BRAND              0.675348
# OS                 0.547559
# VERSION            0.372886
# RAM                0.471320
# MEMORY             0.688139
# DISPLAY            0.409334
# PRIMARYCAMERA      0.425292
# SECONDARYCAMERA    0.264143
# BATTERY            0.132489
# PROCESSOR          0.160979
# DIMENSION         -0.025127
# WEIGHT             0.125209
# TECHNOLOGY         0.185755
# PRICE              1.000000
# Name: PRICE, dtype: float64

# %%
data = data.drop(["MODEL NO","COLOR"],axis = 1)

# %%
def acc(y_test,y_pred):
    
    import math 
    from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
    
    
    
    
    mse = int(mean_squared_error(y_test,y_pred))
    print("r2_score :" , r2_score(y_test,y_pred))
    print("mean_absolute_error :" ,mean_absolute_error(y_test,y_pred))
    print("mean_squared_error : " ,mse)
    print("rmse : ",math.sqrt(mse))
    
    
    
    plt.figure(figsize=(16,6))
    plt.plot(np.arange(53),pd.DataFrame(y_test),marker = '.')
    plt.scatter(np.arange(53),pd.DataFrame(y_pred),color = 'r',marker="*")
    plt.legend(["original results","predicted results"])
    plt.xlabel("Observation",fontsize = 16,color = 'c')
    plt.ylabel("Price",fontsize = 20,color = 'm')
    plt.title('Graphical representation between original results and predicted results',color = 'green',fontsize = 16)
    
    
    y_pred = pd.DataFrame(y_pred)
    y_pred.columns = ["Predicted"]
    
    
    print(pd.concat([pd.DataFrame(y_test).set_index(np.arange(y_test.shape[0])),y_pred],axis = 1))

# %%
def cv(estimator,x,y):
    
    from sklearn.cross_validation import cross_val_score
    min = []
    mean = []
    max = []
  
    
    i = 3
    while(i <=15):
        val = cross_val_score(estimator,x,y,cv = i,scoring='r2')
        min.append(val.min())
        max.append(val.max())
        mean.append(val.mean())
        i = i+1
    
    
    d = { 'min' : min , 'max' : max , "mean" : mean }
    c = pd.DataFrame(d,index = np.arange(3,16,1))
    return c

# %%
x = data.drop(["PRICE"],axis = 1)
y = data["PRICE"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size =0.2,random_state = 2)

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr = GradientBoostingRegressor(min_samples_split=3,random_state=2)
gbr.fit(x_train,y_train)

# %%
y_pred_gbr = gbr.predict(x_test)

# %%
acc(y_test,y_pred_gbr)

# %%
from sklearn.neighbors import KNeighborsRegressor
knr = KNeighborsRegressor()

# %%
knr.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#           weights='uniform')

# %%
y_pred_knr = knr.predict(x_test)

# %%
acc(y_test,y_pred_knr)
# Out:
# r2_score : 0.4215845670796865
# mean_absolute_error : 7644.483018867925
# mean_squared_error :  157201677
# rmse :  12538.009291749628
#     PRICE  Predicted
# 0   19990    25267.2
# 1    7910    16024.0
# 2   73000    68800.0
# 3   27999    33193.6
# 4   25990    17995.2
# 5   74999    17224.0
# 6   12499     6811.6
# 7    8499     5829.2
# 8   25999    12332.2
# 9   12200     8661.4
# 10  12999    36088.0
# 11  27700    37988.0
# 12   7000     8691.4
# 13  16980    10599.0
# 14  25999    10973.4
# 15  12610     8626.8
# 16  15899    17377.0
# 17  13499    13979.0
# 18   8999    11069.8
# 19   9999    13477.4
# 20   6980     7961.4
# 21   8990     8626.8
# 22  17999    13312.4
# 23   7479    35397.2
# 24   8999     5839.6
# 25  20000    11469.8
# 26  10989    15377.0
# 27  10999    30297.4
# 28  15990    16873.8
# 29  11990    12790.0
# 30  64000    46099.6
# 31   9800    12812.4
# 32   3990     6007.2
# 33  13490    29286.0
# 34  10520     5135.4
# 35   7990     8691.4
# 36   4999     7886.8
# 37  14999    15299.0
# 38   8999    11049.2
# 39  27990    20775.2
# 40  17499    16751.2
# 41  18990    19193.6
# 42   6799    15179.0
# 43  32980     9877.6
# 44  12999     8199.0
# 45   9000    17377.0
# 46   9999     9739.2
# 47   4999     5587.2
# 48  11000    12669.8
# 49   7990     8691.4
# 50  60300    37910.0
# 51  10999    13477.4
# 52  49999    28897.4

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_pred_lr = lr.predict(x_test)

# %%
acc(y_test,y_pred_lr)
# Out:
# r2_score : 0.6758204865446815
# mean_absolute_error : 5936.641509433963
# mean_squared_error :  88105469
# rmse :  9386.451352880917
#     PRICE  Predicted
# 0   19990      16990
# 1    7910       9750
# 2   73000      89000
# 3   27999      32999
# 4   25990      17999
# 5   74999      40000
# 6   12499       6199
# 7    8499       5899
# 8   25999      14999
# 9   12200      17199
# 10  12999      26600
# 11  27700      19150
# 12   7000       8999
# 13  16980      12249
# 14  25999      14999
# 15  12610      17199
# 16  15899      14999
# 17  13499      14999
# 18   8999       8999
# 19   9999      14999
# 20   6980       5399
# 21   8990       8999
# 22  17999      10990
# 23   7479      26990
# 24   8999       4499
# 25  20000       9999
# 26  10989      11999
# 27  10999      14999
# 28  15990       9999
# 29  11990      12990
# 30  64000      64000
# 31   9800       9999
# 32   3990       4549
# 33  13490       9490
# 34  10520       5399
# 35   7990       8999
# 36   4999       6138
# 37  14999      19990
# 38   8999       8999
# 39  27990      23358
# 40  17499      10999
# 41  18990      16999
# 42   6799      11999
# 43  32980      29500
# 44  12999      29999
# 45   9000      17500
# 46   9999       8999
# 47   4999       7499
# 48  11000       8999
# 49   7990       8999
# 50  60300      67900
# 51  10999      11999
# 52  49999      14999

# %%
from sklearn.svm import SVR

# %%
svr = SVR(kernel = 'poly')

# %%
svr.fit(x_train,y_train)

# %%
y_pred_svr = svr.predict(x_test)

# %%
y_pred_svr

# %%
acc(y_test,y_pred_svr)
